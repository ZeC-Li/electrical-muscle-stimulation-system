# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
plt.rc('font',family='Times New Roman')

# %%
def listdir(path, list_name):
    for file in os.listdir(path):
        file_path = os.path.join(path, file)
        if os.path.isdir(file_path):
            listdir(file_path, list_name)
        else:
            list_name.append(file_path)
    return list_name

# %%
all_file = []
all_file = listdir(r".//finaladdboxplot", all_file)
all_filename = []
for i in all_file:
    temp_filename = i.split("\\")
    temp_filename = temp_filename[-1].split(".")[0]
    all_filename.append(temp_filename)
print(all_filename)
labels = ['Fuzzy control', 'PID-Modified RNN', 
          'PID-Original RNN', 'PID-PSO', 
          'PID-SOA', 'Fuzzy control', 
          'PID-Modified RNN', 'PID-Original RNN', 
          'PID-PSO', 'SOA']
# Out:
# ['nonvmd_fuzzy_eduis_pow', 'nonvmd_nn_new_eduis_pow', 'nonvmd_nn_old_eduis_pow', 'nonvmd_pso_eduis_pow', 'nonvmd_soa_eduis_pow', 'vmd_fuzzy_eduis_pow', 'vmd_nn_new_eduis_pow', 'vmd_nn_old_eduis_pow', 'vmd_pso_eduis_pow', 'vmd_soa_eduis_pow']

# %%
datalist = []
for i in range(len(all_filename)):
    readfile = pd.read_csv(r".//finaladdboxplot//" + all_filename[i]+".csv")
    readfile = readfile["edu"].tolist()

    datalist.append(readfile)

# %%
plt.figure(dpi=600)
plt.figure(figsize=(15, 12))
plt.rcParams['savefig.dpi'] = 600 #图片像素
plt.rcParams['figure.dpi'] = 600 #分辨率
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False

# 第一个子图，N1np
plt.subplot(4, 1, 1)
# plt.ylim(-50,30) 
# plt.legend("N1",fontsize='x-large', loc=1)
plt.title("Controller without VMD                                         Controller with VMD ", fontdict={'weight':'normal','size': 20})
# plt.boxplot(datalist, labels = labels,
#             notch = True,sym = '*', patch_artist = True, boxprops = {'color':'orangered','facecolor':'green', 'alpha':0.7})
plt.boxplot(datalist, labels = labels,
            notch = True,sym = '*')
# plt.tick_params(
#     axis='x',          # changes apply to the x-axis
#     which='both',      # both major and minor ticks are affected
#     bottom=False,      # ticks along the bottom edge are off
#     top=False,         # ticks along the top edge are off
#     labelbottom=False) # labels along the bottom edge are off
plt.xticks(fontsize=16, rotation = 80)
plt.yticks(fontsize=16)
axes = plt.gca()
left, right = axes.get_xlim()

axes.hlines(y=1.34, xmin=left, xmax=right, linestyles='dashed')

plt.savefig(r'residualbox.eps',dpi=600)
plt.savefig(r'residualbox.svg',dpi=600)

# # 第二个子图，N2np
# plt.subplot(4, 1, 2)
# # plt.ylim(-50,30) 
# # plt.legend("N2",fontsize='x-large', loc=1)
# plt.title("Controller without VMD", fontdict={'weight':'normal','size': 30})
# plt.boxplot(datalist[5:9], labels = labels[5:9], 
#             notch = True,sym = '*')
# # plt.tick_params(
# #     axis='x',          # changes apply to the x-axis
# #     which='both',      # both major and minor ticks are affected
# #     bottom=False,      # ticks along the bottom edge are off
# #     top=False,         # ticks along the top edge are off
# #     labelbottom=False) # labels along the bottom edge are off
# # plt.xticks(fontsize=23)
# # plt.yticks(fontsize=16)
# plt.xticks(fontsize=23, rotation = 0)
# plt.yticks(fontsize=16)
# axes = plt.gca()
# left, right = axes.get_xlim()

# axes.hlines(y=10, xmin=left, xmax=right, linestyles='dashed')
# axes.hlines(y=4, xmin=left, xmax=right, linestyles='dashed')
# axes.hlines(y=19, xmin=left, xmax=right, linestyles='dashed')

# %%
# 第一个子图，N1np
plt.subplot(4, 1, 1)
# plt.ylim(-50,30) 
# plt.legend("N1",fontsize='x-large', loc=1)
plt.title("N1", fontdict={'weight':'normal','size': 30})
# plt.boxplot(datalist, labels = labels,
#             notch = True,sym = '*', patch_artist = True, boxprops = {'color':'orangered','facecolor':'green', 'alpha':0.7})
plt.boxplot([datalist[1],datalist[6]], labels = ["nonvmd_nn", "vmd_nn"], 
            notch = True,sym = '*')
# plt.tick_params(
#     axis='x',          # changes apply to the x-axis
#     which='both',      # both major and minor ticks are affected
#     bottom=False,      # ticks along the bottom edge are off
#     top=False,         # ticks along the top edge are off
#     labelbottom=False) # labels along the bottom edge are off
plt.xticks(fontsize=23, rotation = 45)
plt.yticks(fontsize=16)
axes = plt.gca()
left, right = axes.get_xlim()
# axes.hlines(y=10, xmin=left, xmax=right, linestyles='dashed')
axes.hlines(y=3.23, xmin=left, xmax=right, linestyles='dashed')
# axes.hlines(y=19, xmin=left, xmax=right, linestyles='dashed')

# %%
np.mean(datalist[6])
# Out:
# 1.589964509031672
